# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']=15,10

# %%
import os 
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Adult_income_final.ipynb',
#  'CarPricePrediction.pickle',
#  'catboost_info',
#  'creditcard.csv',
#  'Diabetes Prediction Model.ipynb',
#  'Health_Insurance.ipynb',
#  'Hotel_Bookings_Final.ipynb',
#  'House Price Predicion.ipynb',
#  'ipl.ipynb',
#  'ipl_new.ipynb',
#  'p1.py',
#  'Python.ipynb',
#  'Second Hand Car Price Prediction.ipynb',
#  'T20 World Cup_new.ipynb',
#  'Untitled.ipynb',
#  'World Population by country 2024.ipynb']

# %%
df=pd.read_csv('creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 282003  170589.0 -0.250353  0.881964 -1.953977 -1.478740  2.727852  3.237330
# 250173  154763.0  2.144611 -1.627999 -1.264319 -1.857516 -0.521444  1.010277
# 150754   94015.0  2.046300  0.498479 -2.023702  1.310668  1.149027 -0.926417
# 21084    31455.0 -2.470088  1.445333  1.449623  1.991840  1.299102  2.278487
# 30972    36159.0 -1.760968  0.316130  2.531072  0.711357 -1.130730  1.201271
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 282003  0.085593  1.242136 -0.329511  ...  0.412138  1.196831 -0.022335
# 250173 -1.373011  0.340687 -1.326290  ... -0.079034  0.299681  0.220726
# 150754  0.874575 -0.623381  0.881261  ...  0.037229  0.438316 -0.084453
# 21084   1.572548 -0.616953  0.890520  ... -0.561796  0.758427 -0.232501
# 30972   0.318715  0.490035  0.978229  ... -0.149604  0.107217 -0.457655
#
# ...

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_51eb1_row0_col0, #T_51eb1_row0_col1, #T_51eb1_row0_col2, #T_51eb1_row0_col3, #T_51eb1_row0_col4, #T_51eb1_row0_col5, #T_51eb1_row0_col6, #T_51eb1_row0_col7, #T_51eb1_row0_col8, #T_51eb1_row0_col9, #T_51eb1_row0_col10, #T_51eb1_row0_col11, #T_51eb1_row0_col12, #T_51eb1_row0_col13, #T_51eb1_row0_col14, #T_51eb1_row0_col15, #T_51eb1_row0_col16, #T_51eb1_row0_col17, #T_51eb1_row0_col18, #T_51eb1_row0_col19, #T_51eb1_row0_col20, #T_51eb1_row0_col21, #T_51eb1_row0_col22, #T_51eb1_row0_col23, #T_51eb1_row0_col24, #T_51eb1_row0_col25, #T_51eb1_row0_col26, #T_51eb1_row0_col27, #T_51eb1_row0_col28, #T_51eb1_row0_col29, #T_51eb1_row0_col30 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_51eb1_row1_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# ...

# %%
df.describe().T.plot()
plt.xticks(rotation=90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# class     0
# dtype: int64

# %%
plt.hist(df['Amount'],bins=20,color='orange')
plt.show()

# %%
plt.hist(df['V1'],bins=20,ec='k',color='blue')
plt.show()

# %%
plt.hist(df['V10'],bins=20,ec='k',color='green')
plt.show()

# %%
plt.hist(df['V12'],bins=20,ec='k',color='red')
plt.show()

# %%
sns.distplot(df['class'])
plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_20384\903877964.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['class'])
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.distplot(df['V5'])
plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_20384\195289293.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['V5'])
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(df['V2'],color='orange')
plt.show()

# %%
sns.boxplot(df['V12'],color='blue')
plt.show()

# %%
sns.scatterplot(x=df['Amount'],y=df['class'],data=df,color='Orange')
plt.show()

# %%
sns.scatterplot(x=df['Amount'],y=df['class'],hue=df['V1'],data=df,color='green')
plt.show()

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'class'],
#       dtype='object')

# %%
df['class'].value_counts()
# Out:
# class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df['Amount'].max()
# Out:
# 25691.16

# %%
df['Amount'].min()
# Out:
# 0.0

# %%
df['Amount'].mean()
# Out:
# 88.34961925093133

# %%
df['Amount'].std()
# Out:
# 250.1201092402221

# %%
df['Amount'].sum()
# Out:
# 25162590.009999998

# %%
legit=df[df['class']==0]
fraud=df[df['class']==1]

# %%
legit=pd.DataFrame(legit)
legit
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud=pd.DataFrame(fraud)
fraud.style.background_gradient()
# Out:
# <style type="text/css">
# ...

# %%
legit.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_e51a6_row0_col0, #T_e51a6_row0_col1, #T_e51a6_row0_col2, #T_e51a6_row0_col3, #T_e51a6_row0_col4, #T_e51a6_row0_col5, #T_e51a6_row0_col6, #T_e51a6_row0_col7, #T_e51a6_row0_col8, #T_e51a6_row0_col9, #T_e51a6_row0_col10, #T_e51a6_row0_col11, #T_e51a6_row0_col12, #T_e51a6_row0_col13, #T_e51a6_row0_col14, #T_e51a6_row0_col15, #T_e51a6_row0_col16, #T_e51a6_row0_col17, #T_e51a6_row0_col18, #T_e51a6_row0_col19, #T_e51a6_row0_col20, #T_e51a6_row0_col21, #T_e51a6_row0_col22, #T_e51a6_row0_col23, #T_e51a6_row0_col24, #T_e51a6_row0_col25, #T_e51a6_row0_col26, #T_e51a6_row0_col27, #T_e51a6_row0_col28, #T_e51a6_row0_col29, #T_e51a6_row0_col30 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e51a6_row1_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# ...

# %%
fraud.describe().style.background_gradient()
# Out:
# <style type="text/css">
# ...

# %%
x=df.drop(['class'],axis='columns')
y=df['class']

# %%
x
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: class, Length: 284807, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.8,random_state=1)

# %%
X_train.shape,X_test.shape
# Out:
# ((56961, 30), (227846, 30))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(X_train,Y_train)
y_pred=lr.predict(X_test)
print("The first five predicted values are:")
print(y_pred[0:5])
print("The first five test values are:")
print(Y_test[0:5])
# Out:
# The first five predicted values are:
# [ 0.00108318 -0.00189351  0.00235082 -0.00025844  0.00840664]
# The first five test values are:
# 169876    0
# 127467    0
# 137900    0
# 21513     0
# 134700    0
# Name: class, dtype: int64

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.530351111925737

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(lr,x,y,cv=10))
# Out:
# [0.30753239 0.66580983 0.4996805  0.4488013  0.43460641 0.70094799
#  0.33760283 0.45943091 0.46303061 0.3824893 ]

# %%
print(np.average(cross_val_score(lr,x,y,cv=10)))
# Out:
# 0.46999320661993743

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso()
lasso.fit(X_train,Y_train)
y_pred=lasso.predict(X_test)
print("The first five predicted values are:")
print(y_pred[0:5])
print("The first five test values are:")
print(Y_test[0:5])
# Out:
# The first five predicted values are:
# [0.00139553 0.00182522 0.00178343 0.00230717 0.00179852]
# The first five test values are:
# 169876    0
# 127467    0
# 137900    0
# 21513     0
# 134700    0
# Name: class, dtype: int64

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.00014521776279352583

# %%
print(cross_val_score(lasso,x,y,cv=10))
# Out:
# [-4.19055928e-04 -1.33449252e-06 -2.35947339e-04 -5.17531269e-04
#  -1.06199100e-03 -7.91025361e-04 -5.23710763e-04 -2.25973056e-05
#  -5.02761156e-04 -1.46365958e-04]

# %%
print(np.average(cross_val_score(lasso,x,y,cv=10)))
# Out:
# -0.00042223205732838665

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()
dtr.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtr.predict(X_test)
print("The first five predicted values are:")
print(y_pred[0:5])
print("The first five test values are:")
print(Y_test[0:5])
# Out:
# The first five predicted values are:
# [0. 0. 0. 0. 0.]
# The first five test values are:
# 169876    0
# 127467    0
# 137900    0
# 21513     0
# 134700    0
# Name: class, dtype: int64

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.44123500800403825

# %%
print(cross_val_score(dtr,x,y,cv=10))

# %%
print(np.average(cross_val_score(dtr,x,y,cv=10)))
