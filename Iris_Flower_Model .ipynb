# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

# %%
df=pd.read_csv('Iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 118           7.7          2.6           6.9          2.3   Iris-virginica
# 58            6.6          2.9           4.6          1.3  Iris-versicolor
# 109           7.2          3.6           6.1          2.5   Iris-virginica
# 55            5.7          2.8           4.5          1.3  Iris-versicolor
# 57            4.9          2.4           3.3          1.0  Iris-versicolor

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.replace(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],[1,2,3],inplace=True)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18684\1302689297.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],[1,2,3],inplace=True)

# %%
df['species'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width     species
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    2.000000
# std        0.828066     0.433594      1.764420     0.763161    0.819232
# min        4.300000     2.000000      1.000000     0.100000    1.000000
# 25%        5.100000     2.800000      1.600000     0.300000    1.000000
# 50%        5.800000     3.000000      4.350000     1.300000    2.000000
# 75%        6.400000     3.300000      5.100000     1.800000    3.000000
# max        7.900000     4.400000      6.900000     2.500000    3.000000

# %%
df.describe().plot()
plt.show()

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
explode=[0.1,0,0.05]
labels=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
df['species'].value_counts().plot(kind='pie',labels=labels,explode=explode,shadow=True,autopct='%.2f')
plt.xticks(rotation=90)
plt.show()

# %%
plt.hist(df['sepal_length'],bins=20,ec='k',color='blue')
plt.xlabel('Sepal Length')
plt.show()

# %%
plt.hist(df['petal_width'],bins=20,ec='k',color='orange')
plt.xlabel('Petal Width')
plt.show()

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.distplot(df['petal_length'],color='green')
plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18684\116922185.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_length'],color='green')
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(df['sepal_width'],color='orange')
plt.show()

# %%
sns.regplot(x='species',y='sepal_length',data=df)
x=[1,2,3]
labels=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
plt.xticks(x,labels)
plt.show()

# %%
sns.scatterplot(x=df['species'],y=df['sepal_width'],color='red')
labels=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
x=[1,2,3]
plt.xticks(x,labels)
plt.show()

# %%
from ydata_profiling import ProfileReport

# %%
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# C:\Users\KIIT\AppData\Roaming\Python\Python310\site-packages\ydata_profiling\profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
sns.set()

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width   species
# sepal_length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal_length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal_width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
correlations=df.corr()
sns.heatmap(correlations,annot=True,fmt='0.2f')
plt.show()

# %%
x=df.drop(['species'],axis='columns')
y=df['species']

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: species, Length: 150, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
##Logistic Regression

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)

# %%
##checking the accuracy

from sklearn.metrics import accuracy_score
ac=accuracy_score(y_test,y_pred)
ac
# Out:
# 0.9666666666666667

# %%
##confusion matrix

from sklearn.metrics import confusion_matrix
matrix=metrics.confusion_matrix(y_pred,y_test)
matrix
# Out:
# array([[ 8,  0,  0],
#        [ 0, 10,  0],
#        [ 0,  1, 11]], dtype=int64)

# %%
matrix=metrics.confusion_matrix(y_pred,y_test)
sns.heatmap(matrix,annot=True,cmap='Greens',fmt='0.1f')
plt.xlabel("Predicted Values")
plt.ylabel("Test Values")
plt.title("Confusion Matrix for Logistic Regression model")
plt.show()

# %%
model_accuracies = {}

# List of models to evaluate
models = [
    ('Logistic Regression',LogisticRegression())
]

# Train and evaluate each model
for name, model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    model_accuracies[name] = accuracy

# Create a DataFrame for better visualization
accuracy_df = pd.DataFrame(list(model_accuracies.items()), columns=['Model', 'Accuracy'])

# %%
accuracy_df
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.966667

# %%
import pickle

# %%
model = LogisticRegression()
model.fit(X_train, y_train)

# Save the model as a pickle file
with open('Iris_Flower.pkl', 'wb') as f:
    pickle.dump(model, f)

# Load the saved model
with open('Iris_Flower.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# Function for prediction with user input
def predict_iris(sepal_length, sepal_width, petal_length, petal_width):
    input_data = [[sepal_length, sepal_width, petal_length, petal_width]]
    predicted = loaded_model.predict(input_data)[0]
    return predicted

# Example usage
predicted_species = predict_iris(5.5,3.5,1.3,0.2)
print("Predicted Iris Species:", predicted_species)
# Out:
# Predicted Iris Species: 1
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
